# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns

# %%
data_path = pd.read_excel("D:\jena_climate_2009_2016（处理后的数据） .xlsx" )
data_path.head()
# Out:
#                     时间  气压(毫巴，百帕)  温度 (摄氏度)  热力学温度(开尔文)  \
# 0  01.01.2009 09:00:00     999.69     -7.66      265.52
# 1  02.01.2009 09:00:00     998.35     -4.13      269.16
# 2  03.01.2009 09:00:00    1000.92     -9.46      263.63
# 3  04.01.2009 09:00:00     989.95     -0.72      273.23
# 4  05.01.2009 09:00:00     988.42     -3.11      270.95
#
#    相对于湿度的摄氏温度。露点是空气中水的绝对量的量度，是空气不能保持其中所有水分并且水凝结的温度。  相对湿度%  饱和蒸气压（毫巴）  \
# 0                                             -8.84   91.2       3.43
# 1                                             -4.97   93.8       4.49
# 2                                            -10.69   90.7       2.98
# 3                                             -2.73   86.2       5.79
# 4                                             -4.35   91.1       4.85
#
#    蒸汽压力（毫巴）  蒸气压差（毫巴）  特定湿度, 比温度, 含湿量(g/kg)  水蒸气浓度（毫摩尔每摩尔）  空气密度（克每立方米）  \
# 0      3.13      0.30                  1.95           3.13      1310.14
# ...

# %%
plt.figure(figsize=(16,8))
rc = {'font.sans-serif': 'SimHei',
      'axes.unicode_minus': False}
sns.set(context='notebook', style='ticks', rc=rc)
sns.lineplot(x="气压(毫巴，百帕)",y="温度 (摄氏度)",data=data_path[:10000])
plt.show()

# %%
plt.figure(figsize=(26,16))
sns.pointplot(x='日',y='温度 (摄氏度)',data=data_path[0:50000],hue='月')
rc = {'font.sans-serif': 'SimHei',
      'axes.unicode_minus': False}
plt.show()

# %%
plt.figure(figsize=(30,20))
rc = {'font.sans-serif': 'SimHei',
      'axes.unicode_minus': False}
sns.set(context='notebook', style='ticks', rc=rc)
sns.relplot(x="相对于湿度的摄氏温度。露点是空气中水的绝对量的量度，是空气不能保持其中所有水分并且水凝结的温度。",y="温度 (摄氏度)"
             ,data=data_path[:20000])
plt.show()

# %%
plt.figure(figsize=(16,8))
rc = {'font.sans-serif': 'SimHei',
      'axes.unicode_minus': False}
sns.set(context='notebook', style='ticks', rc=rc)
sns.lineplot(x="风速(m/s)",y="温度 (摄氏度)",data=data_path[:10000])
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.boxplot(x='月',y="温度 (摄氏度)", data=data_path)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.relplot(x="温度 (摄氏度)",y="年",data=data_path)
plt.show()

# %%
plt.figure(figsize=(40,40))
rc = {'font.sans-serif': 'SimHei',
      'axes.unicode_minus': False}
sns.set(context='notebook', style='ticks', rc=rc)
sns.relplot(x="相对湿度%",y="温度 (摄氏度)",hue="月"
             ,data=data_path[:20000])
plt.show()
